# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# 2. Connection (Setup)
# Replace with your actual username/password/host
engine = create_engine('mysql+mysqlconnector://root:H7bR%3Cq48pF2%40@localhost/Brazilian_ecomerce')
folder_path = 'AmyProject'

# 3. Process (The Loop)
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path, file)
        table_name = file.replace('.csv', '')
        
        # Read and Upload
        df = pd.read_csv(file_path)
        df.to_sql(table_name, engine, if_exists='replace', index=False, chunksize=10000)
        print(f"Done: {table_name}")
# Out:
# Done: olist_sellers_dataset
# Done: product_category_name_translation
# Done: olist_orders_dataset
# Done: olist_order_items_dataset
# Done: olist_customers_dataset
# Done: olist_geolocation_dataset
# Done: olist_order_payments_dataset
# Done: olist_order_reviews_dataset
# Done: olist_products_dataset
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 21
#      18         df.to_sql(table_name, engine, if_exists='replace', index=False, chunksize=10000)
#      19         print(f"Done: {table_name}")
# ---> 21 data.head()
#
# NameError: name 'data' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined
